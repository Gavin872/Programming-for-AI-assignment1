# %%
{
 "cells": [
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "imports",
   "metadata": {},
   "outputs": [],
   "source": [
    "import numpy as np\n",
    "from numcompute.io import load_csv\n",
    "from numcompute.preprocessing import Imputer, StandardScaler, OneHotEncoder\n",
    "from numcompute.sort_search import topk, binary_search\n",
    "from numcompute.rank import rank, percentile\n",
    "from numcompute.stats import mean, std, histogram, quantiles, Welford\n",
    "from numcompute.metrics import accuracy, precision, recall, f1, mse\n",
    "from numcompute.optim import grad, jacobian\n",
    "from numcompute.pipeline import Pipeline"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "preprocessing",
   "metadata": {},
   "outputs": [],
   "source": [
    "X = np.array([[1.0, np.nan], [2.0, 5.0], [3.0, 6.0]])\n",
    "pipe = Pipeline([\n",
    "    ('imputer', Imputer(fill_value=0.0)),\n",
    "    ('scaler', StandardScaler())\n",
    "])\n",
    "X_tr = pipe.fit_transform(X)\n",
    "X_tr"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "encoding",
   "metadata": {},
   "outputs": [],
   "source": [
    "cats = np.array(['red', 'blue', 'red'])\n",
    "enc = OneHotEncoder()\n",
    "enc.fit_transform(cats)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "sort-search-rank",
   "metadata": {},
   "outputs": [],
   "source": [
    "values = np.array([10, 4, 8, 2, 9])\n",
    "topk(values, 3)\n",
    "binary_search(np.array([1, 3, 5, 7]), 5)\n",
    "rank(np.array([10, 20, 20, 30]), method='average')\n",
    "percentile(values, 50)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "stats",
   "metadata": {},
   "outputs": [],
   "source": [
    "x = np.array([1, 2, 3, 4, 5], dtype=float)\n",
    "mean(x), std(x), histogram(x, bins=2), quantiles(x, [0.25, 0.5, 0.75])"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "welford",
   "metadata": {},
   "outputs": [],
   "source": [
    "w = Welford().update([1, 2, 3, 4, 5])\n",
    "w.mean, w.variance"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "metrics",
   "metadata": {},
   "outputs": [],
   "source": [
    "y_true = np.array([1, 0, 1, 1])\n",
    "y_pred = np.array([1, 0, 0, 1])\n",
    "accuracy(y_true, y_pred), precision(y_true, y_pred), recall(y_true, y_pred), f1(y_true, y_pred)\n",
    "mse(np.array([1.0, 2.0, 3.0]), np.array([1.0, 2.0, 4.0]))"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "optim",
   "metadata": {},
   "outputs": [],
   "source": [
    "def f(v):\n",
    "    return v[0] ** 2 + v[1] ** 2\n",
    "\n",
    "def F(v):\n",
    "    return np.array([v[0] + v[1], v[0] * v[1]])\n",
    "\n",
    "grad(f, np.array([3.0, 4.0])), jacobian(F, np.array([2.0, 3.0]))"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.11"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
